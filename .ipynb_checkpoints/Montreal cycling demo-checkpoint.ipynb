# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 15)
pd.set_option('display.line_width', 400)
pd.set_option('display.mpl_style', 'default')
rcParams['figure.figsize'] = (14, 7)
import matplotlib
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-614611be13db> in <module>()
#       2 pd.set_option('display.line_width', 400)
#       3 pd.set_option('display.mpl_style', 'default')
# ----> 4 rcParams['figure.figsize'] = (14, 7)
#       5 import matplotlib
#       6 font = {'family' : 'normal',
#
# NameError: name 'rcParams' is not defined

# %%
# %matplotlib inline

# %%
bike_data = pd.read_csv("./2013.csv")
bike_data[:5]
# Out:
#          Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  Totem_Laurier
# 0  01/01/2013      00:00       0    0      1      0     6        0        1              0
# 1  02/01/2013      00:00      69    0     13      0    18        0        2              0
# 2  03/01/2013      00:00      69    2     21      6    22        1        0              0
# 3  04/01/2013      00:00      80    0     22      4    16        0      125              0
# 4  05/01/2013      00:00      52    4     19      3    12        0       97              0

# %%
bike_data = pd.read_csv('./2013.csv', encoding='latin1', sep=';', index_col='Date', parse_dates=True, dayfirst=True)
bike_data[:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cb8cce916691> in <module>()
# ----> 1 bike_data = pd.read_csv('./2013.csv', encoding='latin1', sep=';', index_col='Date', parse_dates=True, dayfirst=True)
#       2 bike_data[:5]
#
# ...

# %%
bike_data[:5]
# Out:
#          Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  Totem_Laurier
# 0  01/01/2013      00:00       0    0      1      0     6        0        1              0
# 1  02/01/2013      00:00      69    0     13      0    18        0        2              0
# 2  03/01/2013      00:00      69    2     21      6    22        1        0              0
# 3  04/01/2013      00:00      80    0     22      4    16        0      125              0
# 4  05/01/2013      00:00      52    4     19      3    12        0       97              0

# %%
bike_data = bike_data.dropna(axis=1)

# %%
bike_data.plot()

# %%
from pylab import *

# %%
import matplotlib.pyplot as plt

# %%
x = [2010, 2011, 2012, 2013, 2014]
y = [5, 7, 9, 23, 500]
z = [5, 7, 9, 23, 500]

# %%
figure()
plot(x, y, 'r')
xlabel('Year')
ylabel('$ Figures')
title('John Malnar`s Salary')
show()

# %%
subplot(1,2,1)
plot(x,y,'r--')
subplot(1,2,2)
plot(y, x, 'g*-');

# %%
subplot(1,2,1)
plot(x, y, 'r--')
subplot(1,2,2)
plot(y, x, 'g*-');

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');
